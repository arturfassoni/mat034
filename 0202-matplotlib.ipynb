# %% [markdown]
# # **Matemática Computacional - Aula 4**
#
# Nesta aula aprenderemos a usar um pacote do Python muito importante para computação científica:
#
# *   Matplotlib: usado para criar vários tipos de gráficos

# %% [markdown]
# # Matplotlib

# %% [markdown]
# [Matplotlib](http://matplotlib.org) é um pacote Python para plotagem 2D e o submódulo `matplotlib.pyplot` contém muitas funções de plotagem para criar vários tipos de gráficos. Vamos começar importando `matplotlib.pyplot`.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plotagem Básica
#
# ### Procedimento
#
# O procedimento geral para criar um gráfico de linha 2D é:
#
# 1. Crie uma sequência de valores $x$.
# 2. Crie uma sequência de valores $y$.
# 3. Digite `plt.plot(x,y,[fmt],**kwargs)` onde `[fmt]` é uma string de formatação (opcional) e `**kwargs` são argumentos de palavra-chave (opcionais) que especificam as propriedades da linha do gráfico.
# 4. Use as funções do `pyplot` para adicionar recursos à figura, como título, legenda, linhas de grade, etc.
# 5. Digite `plt.show()` para exibir a figura resultante.
#
# Vamos começar com um exemplo básico com alguns pontos aleatórios:

# %%
x = [-5,-2,0,1,3]
y = [2,-1,1,-4,3]
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1384753446.py in <cell line: 0>()
#       1 x = [-5,-2,0,1,3]
#       2 y = [2,-1,1,-4,3]
# ----> 3 plt.plot(x,y)
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Os principais pontos a notar são:
#
# 1. As sequências `x` e `y` definem as coordenadas dos pontos no gráfico.
# 2. A linha no gráfico é construída conectando os pontos por linhas retas.
#
# A segunda observação implica que, se quisermos plotar uma curva suave, precisamos plotar muitos pontos, caso contrário, o gráfico não será suave. Por exemplo, poderíamos tentar plotar a parábola $y = x^2$ para $x \in [-2,2]$ usando apenas 5 pontos:

# %%
x = [-2,-1,0,1,2]
y = [4,1,0,1,4]
plt.plot(x,y)
plt.show()

# %% [markdown]
# Isso são poucos pontos para plotar uma curva suave como $y = x^2$ e, portanto, precisamos de mais pontos! Vamos tentar novamente usando a função do NumPy `np.linspace` para criar 100 pontos!

# %%
x = np.linspace(-2,2,100+1)
y = x**2
plt.plot(x,y)
plt.show()

# %% [markdown]
# Essa é uma representação melhor da parábola $y = x^2$. Note que o número de pontos que usamos em um gráfico de linha (100 neste caso) é completamente arbitrário, mas o objetivo é mostrar um gráfico suave para uma curva suave e, portanto, só precisamos escolher um número grande o suficiente, dependendo da função. Mas tenha cuidado para não gerar muitos pontos, pois um número *muito* grande de pontos levará *muito* tempo para plotar!
#
# Agora que temos a ideia geral, vamos ver como adicionar estilo e recursos aos nossos gráficos!

# %%
x = np.linspace(-np.pi,np.pi,100+1)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Propriedades da Linha
#
# Uma linha que aparece em um gráfico tem várias propriedades, incluindo cor, transparência, estilo, largura e marcadores. Podemos definir essas propriedades quando chamamos `plt.plot` usando os seguintes argumentos de palavra-chave:
#
# | Propriedade | Descrição |
# | :---: | :--- |
# | `alpha` | transparência (0.0 transparente a 1.0 opaco) |
# | `color` (ou `c`) | qualquer cor do matplotlib |
# | `label` | texto que aparece na legenda |
# | `linestyle` (ou `ls`) | `solid`, `dashed`, `dashdot`, `dotted` |
# | `linewidth` (ou `lw`) | define a largura da linha |
# | `marker` | define o estilo do marcador |
# | `markeredgecolor` (ou `mec`) | qualquer cor do matplotlib |
# | `markerfacecolor` (ou `mfc`) | qualquer cor do matplotlib |
# | `markersize` (ou `ms`) | tamanho do marcador |
#
# Observe que podemos especificar uma [cor do matplotlib](https://matplotlib.org/api/colors_api.html) de várias maneiras diferentes, incluindo pelo nome, como `blue` ou `red`, ou por uma tupla [RGB](https://www.w3schools.com/colors/colors_rgb.asp), como `(1,0,1)` para roxo. Por exemplo, vamos plotar a função
#
# $$
# y = e^{-x^2}\cos(2 \pi x) \ \ , \ \ x \in [-2,2]
# $$

# %%
x_inicial = -2
x_final = 2
n_pontos = 80
x = np.linspace(x_inicial,x_final,n_pontos+1)
y = np.exp(-x**2) * np.cos(2*np.pi*x)
plt.plot(x,y
         ,alpha=0.4,label='Decaying Cosine',
         color='red',linestyle='dashed',linewidth=2,
         marker='v',markersize=5,markerfacecolor='blue',
         markeredgecolor='green'
         )
plt.ylim([-2,2])
plt.legend()
plt.show()

# %% [markdown]
# Note que usamos a função do pyplot `plt.legend` para exibir a figura com uma legenda (mostrando o rótulo da linha) e `plt.ylim` para definir os limites no eixo vertical para `[-2,2]`.

# %% [markdown]
# ### Strings de Formatação
#
# Uma [string de formatação](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib-pyplot-plot) nos dá um atalho para adicionar cor, marcadores e estilo de linha a um gráfico de linha. Por exemplo, se quisermos plotar a função
#
# $$
# y = \frac{1}{1 + x^2} \ , \ x \in [-5,5]
# $$
#
# com uma linha preta tracejada e marcadores quadrados, poderíamos usar argumentos de palavra-chave:

# %%
x = np.linspace(-5,5,41)
y = 1/(1 + x**2)
plt.plot(x,y,color='black',linestyle='dashed',marker='s',linewidth=3)
plt.show()

# %% [markdown]
# Ou poderíamos usar a string de formatação correspondente `'ks--'` onde `k` denota uma linha preta, `s` um marcador quadrado e `--` uma linha tracejada:

# %%
x = np.linspace(-5,5,41)
y = 1/(1 + x**2)
plt.plot(x,y,'ks--',lw=3)
plt.show()

# %% [markdown]
# Muito mais fácil! Veja abaixo uma lista de cores, marcadores e estilos de linha.

# %% [markdown]
# #### Cores
#
# | Caractere | Cor |
# | :---: | :---: |
# | `b` | azul |
# | `g` | verde |
# | `r` | vermelho |
# | `c` | ciano |
# | `m` | magenta |
# | `y` | amarelo |
# | `k` | preto |
# | `w` | branco |
#
# #### Marcadores
#
# | Caractere | Marcador |
# | :---: | :---: |
# | `.` | ponto |
# | `o` | círculo |
# | `v` | triângulo para baixo |
# | `^` | triângulo para cima |
# | `s` | quadrado |
# | `p` | pentágono |
# | `*` |	estrela |
# | `+` | mais |
# | `x` |	x |
# | `D` | diamante |
#
# #### Estilos de Linha
#
# | Caractere | Estilo de Linha |
# | :---: | :---: |
# | `-` | estilo de linha sólida |
# | `--` | estilo de linha tracejada |
# | `-.` | estilo de linha traço-ponto |
# | `:` | estilo de linha pontilhada |
#
# Veja a [documentação do matplotlib.pyplot.plot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html) para mais opções.

# %% [markdown]
# ### Funções do Pyplot
#
# Existem muitas funções do `pyplot` disponíveis para personalizarmos nossas figuras. Por exemplo:
#
# | Função | Descrição |
# | ---: | :--- |
# | `plt.xlim` | define os limites de x |
# | `plt.ylim` | define os limites de y |
# | `plt.grid` | adiciona linhas de grade |
# | `plt.title` | adiciona um título |
# | `plt.xlabel` | adiciona um rótulo ao eixo horizontal |
# | `plt.ylabel` | adiciona um rótulo ao eixo vertical |
# | `plt.axis` | define as propriedades dos eixos (`equal`, `off`, `scaled`, etc.) |
# | `plt.xticks` | define as posições dos ticks (marcas) no eixo horizontal |
# | `plt.yticks` | define as posições dos ticks (marcas) no eixo vertical |
# | `plt.legend` | exibe a legenda para várias linhas na mesma figura |
# | `plt.savefig` | salva a figura (como .png, .pdf, etc.) no diretório de trabalho |
# | `plt.figure` | cria uma nova figura e define suas propriedades |
#
# Consulte a [documentação do pyplot](https://matplotlib.org/api/pyplot_summary.html) para uma lista completa de funções.

# %% [markdown]
# ## Exemplos

# %% [markdown]
# ### Polinômios de Taylor
#
# Plote a função $y = \cos(x)$ juntamente com seus [polinômios de Taylor](https://en.wikipedia.org/wiki/Taylor_series) de graus 2 e 4.

# %%
x = np.linspace(-6,6,50)

# Plot y = cos(x)
y = np.cos(x)
plt.plot(x,y,'b',label='cos(x)')

# Plot degree 2 Taylor polynomial
y2 = 1 - x**2/2
plt.plot(x,y2,'r-.',label='Degree 2')

# Plot degree 4 Taylor polynomial
y4 = 1 - x**2/2 + x**4/24
plt.plot(x,y4,'g:',label='Degree 4')

# Add features to our figure
plt.legend()
plt.grid(True,linestyle=':',alpha=0.3)
plt.yticks(np.arange(-6,6.1,0.5))
plt.xlim([-6,6])
plt.ylim([-3,3])
plt.title('Taylor Polynomials of cos(x) at x=0')
plt.xlabel('eixo x')
plt.ylabel('eixo y')

plt.show()

# %% [markdown]
# ### Curva do Coração
#
# Plote a curva do coração:
#
# \begin{align}
# x &= 16 \sin^3(t) \\\
# y &= 13 \cos(t) - 5 \cos(2t) - 2 \cos(3t) - \cos(4t)
# \end{align}
#
# para $t \in [0,2\pi]$.

# %%
t = np.linspace(0,2*np.pi,100)

x = 16*np.sin(t)**3
y = 13*np.cos(t) - 5*np.cos(2*t) - 2*np.cos(3*t) - np.cos(4*t)

# Plot line with RGB tuple (red=1, green=0.2, blue=0.5)
# and 20pt line width
plt.plot(x,y,c=(1,0.2,0.5),lw=20)

# Add features to our figure
plt.title('Heart!')
plt.axis('equal')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Subplots (Gráficos Múltiplos)
#
# A função `plt.subplot` recebe pelo menos 3 entradas $n$, $m$ e $i$ e cria uma figura com uma grade de $n$ por $m$ subplots e, em seguida, define o $i$-ésimo subplot (contando ao longo das linhas) como o gráfico atual (ou seja, o objeto de eixos atual).
#
# Por exemplo, considere a [onda dente de serra](https://en.wikipedia.org/wiki/Sawtooth_wave)
#
# $$
# f(t) = \frac{1}{2} - \frac{1}{\pi} \sum_{k=1}^{\infty} (-1)^k \frac{\sin(2 \pi k t)}{k}
# $$
#
# e seja $f_N(t)$ a $N$-ésima soma parcial da onda dente de serra:
#
# $$
# f_N(t) = \frac{1}{2} - \frac{1}{\pi} \sum_{k=1}^{N} (-1)^k \frac{\sin(2 \pi k t)}{k}
# $$
#
# Crie uma grade de 2 por 2 de subplots para plotar as 4 primeiras somas parciais:
#
# \begin{align}
# f_1(t) &= \frac{1}{2} + \frac{\sin(2 \pi t)}{\pi} \\\
# f_2(t) &= \frac{1}{2} + \frac{\sin(2 \pi t)}{\pi} - \frac{\sin(4 \pi t)}{2\pi} \\\
# f_3(t) &= \frac{1}{2} + \frac{\sin(2 \pi t)}{\pi} - \frac{\sin(4 \pi t)}{2\pi} + \frac{\sin(6 \pi t)}{3\pi} \\\
# f_4(t) &= \frac{1}{2} + \frac{\sin(2 \pi t)}{\pi} - \frac{\sin(4 \pi t)}{2\pi} + \frac{\sin(6 \pi t)}{3\pi} - \frac{\sin(8 \pi t)}{4\pi}
# \end{align}

# %%
t = np.linspace(0,4,200)

fN = 1/2
for k in [1,2,3,4,5,6]:
    fN = fN - (-1)**k * np.sin(2*k*np.pi*t)/(k*np.pi)
    plt.subplot(3,2,k)
    plt.plot(t,fN)
    plt.title('N = {}'.format(k))

plt.tight_layout()
plt.show()

# %% [markdown]
# Veja a [documentação](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html) para mais informações sobre subplots.

# %% [markdown]
# ## Além dos Gráficos de Linha
#
# ### Gráficos de Dispersão (Scatter plots)
#
# Um [gráfico de dispersão](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html) tem 4 dimensões: coordenada $x$, coordenada $y$, tamanho e cor. Vamos fazer um gráfico de dispersão aleatório:

# %%
# Set the number of dots in the plot
N = 2000

# Create random x and y coordinates sampled uniformly from [0,1]
x = np.random.rand(N)
y = np.random.rand(N)

# Create random array sampled uniformly from [20,120]
# `size` array is used below to set the size of each dot
size = 100*np.random.rand(N) + 20

# Create random 4-tuples sampled uniformly from [0,1]
# `colors` array is used below to set the color
# (red,green,blue,alpha) of each dot
colors = np.random.rand(N,4)

# Create a figure of size 12 by 5 and create scatter plot
plt.figure(figsize=(7,5))
plt.scatter(x,y,c=colors,s=size)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Histogramas
#
# Gere um array de 10000 números aleatórios amostrados da distribuição normal e crie um [histograma](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html). Vamos também sobrepor a distribuição normal:
#
# $$
# y = \frac{1}{\sqrt{2\pi}} e^{-x^2/2}
# $$

# %%
samples = np.random.randn(10000)
plt.hist(samples,bins=20,density=True,alpha=0.5,color=(0.3,0.8,0.1))
plt.title('Random Samples - Normal Distribution')
plt.ylabel('Frequency')

x = np.linspace(-4,4,100)
y = 1/(2*np.pi)**0.5 * np.exp(-x**2/2)
plt.plot(x,y,'b',alpha=0.8)

plt.show()

# %% [markdown]
# ### Gráficos de Barras (Bar plots)
#
# Plote a [precipitação total em Vancouver](https://vancouver.weatherstats.ca/charts/precipitation-monthly.html) por mês como um [gráfico de barras](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.bar.html):

# %%
month = range(1,13)
precipitation = [98.8,128.8,206.0,138.5,102.2,46.4,1.8,5.0,29.4,114.8,197.0,170.6]

plt.bar(month,precipitation)

plt.xticks(month,['J','F','M','A','M','J','J','A','S','O','N','D'])
y_ticks = list(range(0,300,50))
y_ticks.append(230)
plt.yticks(y_ticks)
plt.grid(True,alpha=0.5,linestyle='--')
plt.title('Precipitation in Vancouver, 2017')
plt.ylabel('Total Precipitation (mm)')
plt.xlabel('Month')

plt.show()

# %% [markdown]
# ## Objetos Figure e Axes
#
# Até agora, usamos o `pyplot` (`plt`) para criar gráficos de forma "automática". Funções como `plt.plot()` e `plt.title()` atuam na figura ou no gráfico que estiver "ativo" no momento. Essa é a **interface baseada em estado** (state-based) do Matplotlib. Ela é ótima para gráficos rápidos e simples.
#
# No entanto, para ter mais controle, especialmente ao criar múltiplos gráficos em uma única figura, usamos a **interface orientada a objetos**. Essa abordagem é mais explícita e robusta.
#
# Os dois objetos centrais são:
#
# * **`Figure`**: É o contêiner de mais alto nível, a "tela" ou a janela inteira onde tudo é desenhado. Uma `figure` pode conter um ou mais objetos `Axes`.
# * **`Axes`**: É o gráfico em si, a área onde os dados são plotados com eixos x e y, títulos, legendas, etc. **Não confunda `Axes` (o objeto) com `axis` (eixo, como x ou y)**. Um objeto `Axes` contém dois (ou três, em 3D) objetos `Axis`.
#
# A maneira mais comum de começar é com a função `plt.subplots()`. Ela cria uma figura e um conjunto de subplots (os objetos `Axes`) de uma só vez.

# %%
# Criar os objetos Figure e Axes
# fig é a tela inteira, ax é o nosso gráfico
fig, ax = plt.subplots()

# Agora usamos os métodos do objeto 'ax' para plotar
x = np.linspace(0, 10, 200)
y = np.sin(x) * np.exp(-0.1 * x)

ax.plot(x, y)

plt.show()

# %% [markdown]
# Note que, em vez de `plt.funcao()`, agora chamamos `ax.metodo()`. A sintaxe é um pouco diferente, mas muito mais clara. Muitos dos métodos para configurar o gráfico usam o prefixo `set_`.
#
# | Interface `pyplot` (baseada em estado) | Interface Orientada a Objetos (em um objeto `ax`) |
# | :--- | :--- |
# | `plt.plot(x, y)` | `ax.plot(x, y)` |
# | `plt.title('Título')` | `ax.set_title('Título')` |
# | `plt.xlabel('Eixo X')` | `ax.set_xlabel('Eixo X')` |
# | `plt.ylabel('Eixo Y')` | `ax.set_ylabel('Eixo Y')` |
# | `plt.grid(True)` | `ax.grid(True)` |
# | `plt.legend()` | `ax.legend()` |
# | `plt.xlim([0, 10])` | `ax.set_xlim([0, 10])` |
#
# A verdadeira vantagem da abordagem orientada a objetos se torna clara ao trabalhar com múltiplos subplots em uma única figura.

# %%
# Criar uma figura com 1 linha e 2 colunas de subplots
# axs agora é um array de objetos Axes
fig, axs = plt.subplots(1,2, figsize=(12, 5)) # figsize controla o tamanho total da figura

# ---------- Gráfico 1 (à esquerda) ----------
x1 = np.linspace(0, 2 * np.pi, 100)
y1 = np.cos(x1)
axs[0].plot(x1, y1, color='blue',linestyle='--',label='cos x')
axs[0].set_title('Gráfico de Cosseno')
axs[0].set_xlabel('Ângulo [rad]')
axs[0].set_ylabel('Amplitude')
axs[0].grid(True,alpha=0.2,c='gray')
axs[0].legend()


# ---------- Gráfico 2 (à direita) ----------
x2 = np.linspace(-3, 3, 100)
y2 = np.exp(-x2**2)
axs[1].plot(x2, y2, color='red')
axs[1].set_title('Curva Gaussiana')
axs[1].set_xlabel('x')
# O ylabel do segundo gráfico pode ser omitido para um visual mais limpo
axs[1].grid(True,alpha=0.1)

# Ajusta o layout para evitar sobreposição de títulos/rótulos
plt.tight_layout()

plt.show()

# %% [markdown]
# Com essa abordagem, temos controle total sobre cada subplot individualmente, acessando-os pelo índice `axs[0]`, `axs[1]`, etc. Isso torna a criação de dashboards e visualizações complexas muito mais organizada e gerenciável.

# %% [markdown]
# # Exercícios

# %% [markdown]
# **Exercício 1.** Plote as seguintes funções:
#
# * $f(x) = \sqrt{|x|}$, $x \in [-9,9]$
# * $f(x) = \sin(x) + \sin(2x)$, $x \in [0,4\pi]$
# * $f(x) = \arctan(x)$, $x \in [-5,5]$
# * $f(x) = 2x\ln|x|$, $x \not=0$, $f(0)=0$, $x \in [-1,1]$
# * $f(x) = (x+2)(x+1)(x-1)(x-2)(x - 3)$, $x \in [-2,3]$
# * $f(x) = e^{-x^2}$, $x \in [-2,2]$

# %%
x_inicial = -9
x_final = 9
y_inicial = 0
y_final = 3.5
n_pontos = 80
x = np.linspace(x_inicial,x_final,n_pontos+1)
y = abs(x)**(1/2)
plt.plot(x,y,color='red')
plt.xlim([x_inicial,x_final])
plt.ylim([y_inicial,y_final])
plt.show()

# %% [markdown]
# **Exercício 2.** Plote a [curva do oito](https://en.wikipedia.org/wiki/Lemniscate_of_Gerono):
#
# \begin{align}
# x &= \sin(t) \\\
# y &= \sin(t) \cos(t)
# \end{align}
#
# para $t \in [0,2\pi]$.

# %% [markdown]
# **Exercício 3.** Plote o [nó de trevo](https://en.wikipedia.org/wiki/Trefoil_knot):
#
# \begin{align}
# x &= \sin t + 2 \sin 2t \\\
# y &= \cos t - 2 \cos 2t
# \end{align}
#
# para $t \in [0,2\pi]$.

# %% [markdown]
# **Exercício 4.** Plote a [curva da borboleta](https://en.wikipedia.org/wiki/Butterfly_curve_%28transcendental%29):
#
# \begin{align}
# x &= \sin(t) \left( e^{\cos t } - 2 \cos(4t) - \sin^5(t/12) \right) \\\
# y &= \cos(t) \left( e^{\cos t } - 2 \cos(4t) - \sin^5(t/12) \right)
# \end{align}
#
# para $t \in [0,100]$.

# %% [markdown]
# **Exercício 5.** Escreva uma função chamada `parametric_plots` que receba os parâmetros de entrada `a` e `k` e plote a equação paramétrica
#
# \begin{align}
# x(t) &= 2 k \cos(t) - a \cos(k t) \\\
# y(t) &= 2 k \sin(t) - a \sin(k t)
# \end{align}
#
# para $t \in [0,2\pi]$. Inclua um título para cada subplot para exibir os valores de `a` e `k`, e use `plt.axis('equal')` para exibir a curva corretamente.

# %% [markdown]
# **Exercício 6: Histograma e Distribuição Teórica**
#
# A lei dos grandes números sugere que a distribuição de uma amostra aleatória se aproxima da distribuição teórica à medida que o tamanho da amostra aumenta. Vamos visualizar isso.
#
# 1.  Gere um array NumPy com 10.000 amostras de uma [distribuição normal (gaussiana)](https://pt.wikipedia.org/wiki/Distribui%C3%A7%C3%A3o_normal) com média $\mu = 0$ e desvio padrão $\sigma = 1$. Use a função `np.random.randn()`.
# 2.  Crie um histograma dessas amostras usando `plt.hist()`. Use 30 barras (`bins=30`) e normalize o histograma para que a área total seja 1 (use o argumento `density=True`). Deixe as barras semi-transparentes (`alpha=0.6`).
# 3.  Sobre o mesmo gráfico, plote a curva da função densidade de probabilidade (FDP) teórica da distribuição normal, dada pela fórmula:
#     $$f(x) = \frac{1}{\sigma\sqrt{2\pi}} e^{ - \frac{1}{2} (\frac{x-\mu}{\sigma})^2 }$$
# 4.  Adicione um título, rótulos para os eixos e uma legenda para diferenciar o histograma da curva teórica.
#
# **Dica:** Para a curva teórica, crie um array de `x` com `np.linspace()` de -4 a 4 e calcule o `y` correspondente usando a fórmula.

# %% [markdown]
# **Exercício 7: Visualização de Superfície 3D**
#
# Matplotlib também pode criar gráficos 3D. Um uso comum é plotar uma função $z = f(x, y)$.
#
# 1.  Crie dois arrays 1D, `x` e `y`, usando `np.linspace()` de -5 a 5 com 100 pontos cada.
# 2.  Use `np.meshgrid(x, y)` para criar duas matrizes de coordenadas 2D, `X` e `Y`.
# 3.  Calcule a matriz `R` como $R = \sqrt{X^2 + Y^2}$.
# 4.  Calcule a matriz `Z` usando a função `sinc`: $Z = \frac{\sin(R)}{R}$.
# 5.  Crie uma figura e um subplot 3D. Para isso, você precisará primeiro importar `Axes3D`: `from mpl_toolkits.mplot3d import Axes3D`.
# 6.  Use o método `ax.plot_surface(X, Y, Z, cmap='viridis')` para plotar a superfície. `cmap` define o mapa de cores.
# 7.  Adicione um título ao gráfico.

# %% [markdown]
# **Exercício 8: Visualizando uma Matriz com `imshow` (Mapa de Calor)**
#
# Uma matriz 2D do NumPy pode ser visualizada como uma imagem ou um mapa de calor, onde o valor de cada elemento corresponde a uma cor.
#
# 1.  Crie um array 1D `t` de 0 a $2\pi$ com 200 pontos usando `np.linspace()`.
# 2.  Crie uma matriz `M` 100x100 onde cada elemento `M[i, j]` é dado pela função $f(i, j) = \sin(0.1 \times i) + \cos(0.1 \times j)$. Você pode usar `np.outer()` para uma solução elegante ou um loop `for` aninhado.
# 3.  Use `plt.imshow(M, cmap='plasma')` para exibir a matriz como um mapa de calor.
# 4.  Adicione uma barra de cores para servir como legenda para os valores usando `plt.colorbar()`.
# 5.  Adicione um título apropriado para a visualização.

# %% [markdown]
# **Exercício 9: Gráfico de Dispersão (Scatter Plot) com Múltiplas Dimensões**
#
# Gráficos de dispersão são ótimos para visualizar a relação entre variáveis. Podemos codificar informações extras usando cor e tamanho dos pontos.
#
# 1.  Gere 4 arrays NumPy de 100 elementos cada:
#     * `x`: números aleatórios da distribuição uniforme entre 0 e 10.
#     * `y`: `2*x + 1 + np.random.randn(100) * 2` (uma relação linear com um pouco de ruído gaussiano).
#     * `cores`: um array com valores `x * y`. Será usado para mapear a cor de cada ponto.
#     * `tamanhos`: um array de inteiros aleatórios entre 10 e 200. Será usado para definir o tamanho de cada ponto.
# 2.  Use `plt.scatter()` para criar o gráfico. Passe os 4 arrays para os argumentos `x`, `y`, `c` (cor) e `s` (tamanho, de *size*).
# 3.  Use `alpha=0.7` para dar um pouco de transparência e `cmap='viridis'` para o mapa de cores.
# 4.  Adicione uma barra de cores (`plt.colorbar()`) e dê um rótulo a ela para explicar o que as cores significam.
# 5.  Adicione título e rótulos para os eixos x e y.

# %% [markdown]
# **Exercício 10: Subplots com a Interface Orientada a Objetos**
#
# Use a função `plt.subplots()` para criar uma grade de gráficos 2x2 e plote as quatro primeiras [funções de Bessel do primeiro tipo](https://pt.wikipedia.org/wiki/Fun%C3%A7%C3%A3o_de_Bessel) ($J_0, J_1, J_2, J_3$).
#
# 1.  Crie uma figura e um array de eixos `axs` usando `fig, axs = plt.subplots(2, 2, figsize=(10, 8))`.
# 2.  Crie um array `x` de 0 a 15 com 200 pontos.
# 3.  Use um loop `for` de `n` de 0 a 3. Dentro do loop:
#     * Determine em qual subplot (`ax`) desenhar. Uma forma fácil é iterar sobre `axs.flat`, que achata o array 2D de eixos em um array 1D.
#     * Calcule a função de Bessel $J_n(x)$ usando `scipy.special.jv(n, x)`. (Você precisará de `from scipy.special import jv`).
#     * Use `ax.plot()` para desenhar no subplot correto.
#     * Use `ax.set_title()` para dar um título a cada subplot, como `f'Função de Bessel J_{n}(x)'`.
#     * Use `ax.grid(True)` para adicionar uma grade a cada subplot.
# 4.  Use `plt.tight_layout()` no final para ajustar o espaçamento entre os gráficos.
# 5.  Exiba o gráfico com `plt.show()`.
